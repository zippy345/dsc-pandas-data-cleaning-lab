# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
#Load the heroes dataset
heroes_df =pd.read_csv('heroes_information.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Method1!
# Re-load with read_csv, and specify the parameter index_col=0
heroes_df =pd.read_csv('heroes_information.csv',index_col=0)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
# Method2!
# Drop the column Unnamed: 0 with axis=1
heroes_df =pd.read_csv('heroes_information.csv')
heroes_df.drop('Unnamed: 0', axis=1,inplace=True)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %%
heroes_df.shape[1]
# Out:
# 10

# %%
heroes_df.columns
# Out:
# Index(['name', 'Gender', 'Eye color', 'Race', 'Hair color', 'Height',
#        'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == [
    "name",
    "Gender",
    "Eye color",
    "Race",
    "Hair color",
    "Height",
    "Publisher",
    "Skin color",
    "Alignment",
    "Weight",
]

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# print out the size of the dataframe
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        734 non-null    object
#  1   Gender      734 non-null    object
#  2   Eye color   734 non-null    object
#  3   Race        734 non-null    object
#  4   Hair color  734 non-null    object
#  5   Height      734 non-null    float64
#  6   Publisher   719 non-null    object
#  7   Skin color  734 non-null    object
#  8   Alignment   734 non-null    object
#  9   Weight      732 non-null    float64
# dtypes: float64(2), object(8)
# memory usage: 57.5+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %% [markdown]
# #### The interpretation for the analysis
# * The datatypes align with the results, but there are columns with missing values,example the  **Publisher** and the **Weight** columns.
# """

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
#load the second dataset (create more cells as needed)
powers_df=pd.read_csv('super_hero_powers.csv', index_col=0)
powers_df.head()
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
#
# [5 rows x 667 columns]

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == "3-D Man"

# The last column should be 'Zoom'
assert powers_df.columns[-1] == "Zoom"

# The first index should be 'Agility'
assert powers_df.index[0] == "Agility"

# The last index should be 'Omniscient'
assert powers_df.index[-1] == "Omniscient"

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(
    5, random_state=1
)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(
    5, random_state=1
)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %% [markdown]
# #### Replace None with appropriate text
# * Among the two strategies i choose dropping of the rows with the missing values since the appropriate way to avoid bias informations while may not affect the data within the data frame.

# %% [markdown]
# Now, implement the strategy to drop rows with missing values using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Write a code that drops the rows with the missing values within the publisher column
heroes_df.dropna(subset=['Publisher'], inplace=True)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Publisher
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# Marvel                 9
# Star Trek              6
# HarperCollins          6
# Team Epic TV           5
# SyFy                   5
# IDW Publishing         4
# Icon Comics            4
# ABC Studios            4
# Shueisha               4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# Titan Books            1
# Microsoft              1
# Rebellion              1
# Hanna-Barbera          1
# J. K. Rowling          1
# Universal Studios      1
# South Park             1
# J. R. R. Tolkien       1
# Name: count, dtype: int64

# %%
#print the unique values to visibly see the two cases where we appear to have data entry issues
heroes_df['Publisher'].unique()
# Out:
# array(['Marvel Comics', 'Dark Horse Comics', ' DC Comics', 'NBC - Heroes',
#        'DC Comics', 'Wildstorm', 'Image Comics', 'Icon Comics', 'SyFy',
#        'Hanna-Barbera', 'George Lucas', 'Team Epic TV', 'South Park',
#        'HarperCollins', 'ABC Studios', 'Universal Studios', 'Star Trek',
#        'IDW Publishing', 'Marvel', 'Shueisha', 'Sony Pictures',
#        'J. K. Rowling', 'Titan Books', 'Rebellion', 'Microsoft',
#        'J. R. R. Tolkien'], dtype=object)

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
Marvel vs Marvel Comics and  'DC Comics' vs ' DC Comics'.
"""
# Out:
# "\nMarvel vs Marvel Comics and  'DC Comics' vs ' DC Comics'.\n"

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
# Your code here
heroes_df['Publisher'].replace({'Marvel':'Marvel Comics', ' DC Comics':'DC Comics'}, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5712\3967638090.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   heroes_df['Publisher'].replace({'Marvel':'Marvel Comics', ' DC Comics':'DC Comics'}, inplace=True)

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Publisher
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# George Lucas          14
# Image Comics          14
# Star Trek              6
# HarperCollins          6
# SyFy                   5
# Team Epic TV           5
# Icon Comics            4
# ABC Studios            4
# IDW Publishing         4
# Shueisha               4
# Wildstorm              3
# Sony Pictures          2
# Hanna-Barbera          1
# South Park             1
# Universal Studios      1
# J. K. Rowling          1
# Titan Books            1
# Rebellion              1
# Microsoft              1
# J. R. R. Tolkien       1
# Name: count, dtype: int64

# %%
#write a code to confirm the changes
heroes_df["Publisher"].unique()
# Out:
# array(['Marvel Comics', 'Dark Horse Comics', 'DC Comics', 'NBC - Heroes',
#        'Wildstorm', 'Image Comics', 'Icon Comics', 'SyFy',
#        'Hanna-Barbera', 'George Lucas', 'Team Epic TV', 'South Park',
#        'HarperCollins', 'ABC Studios', 'Universal Studios', 'Star Trek',
#        'IDW Publishing', 'Shueisha', 'Sony Pictures', 'J. K. Rowling',
#        'Titan Books', 'Rebellion', 'Microsoft', 'J. R. R. Tolkien'],
#       dtype=object)

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes")
plt.show()

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 4            Abraxas    Male      blue      Cosmic Entity             Black
# ..               ...     ...       ...                ...               ...
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight
# 0     203.0      Marvel Comics          -      good   441.0
# 1     191.0  Dark Horse Comics       blue      good    65.0
# 2     185.0          DC Comics        red      good    90.0
# 3     203.0      Marvel Comics          -       bad   441.0
# 4     -99.0      Marvel Comics          -       bad   -99.0
# ..      ...                ...        ...       ...     ...
# 729   165.0      Marvel Comics          -      good    52.0
# 730   304.8      Marvel Comics      white      good   -99.0
# 731    66.0       George Lucas      green      good    17.0
# 732   170.0          DC Comics          -      good    57.0
# 733   185.0          DC Comics          -       bad    81.0
#
# [719 rows x 10 columns]

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# ...                        ...     ...         ...       ...          ...
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# ...                        ...            ...          ...           ...
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...  Wonder Man  Wonder Woman   X-23  X-Man  \
# Agility                    False  ...       False         False   True  False
# Accelerated Healing        False  ...       False          True   True  False
# Lantern Power Ring         False  ...       False         False  False  False
# Dimensional Awareness      False  ...       False         False  False  False
# Cold Resistance            False  ...       False         False  False  False
# ...                          ...  ...         ...           ...    ...    ...
# Phoenix Force              False  ...       False         False  False  False
# Molecular Dissipation      False  ...       False         False  False  False
# Vision - Cryo              False  ...       False         False  False  False
# Omnipresent                False  ...       False         False  False  False
# Omniscient                 False  ...       False         False  False  False
#
#                        Yellowjacket  Yellowjacket II   Ymir   Yoda  Zatanna  \
# Agility                       False            False  False   True    False
# Accelerated Healing           False            False  False  False    False
# Lantern Power Ring            False            False  False  False    False
# Dimensional Awareness         False            False  False  False    False
# Cold Resistance               False            False   True  False    False
# ...                             ...              ...    ...    ...      ...
# Phoenix Force                 False            False  False  False    False
# Molecular Dissipation         False            False  False  False    False
# Vision - Cryo                 False            False  False  False    False
# Omnipresent                   False            False  False  False    False
# Omniscient                    False            False  False  False    False
#
#                         Zoom
# Agility                False
# Accelerated Healing    False
# Lantern Power Ring     False
# Dimensional Awareness  False
# Cold Resistance        False
# ...                      ...
# Phoenix Force          False
# Molecular Dissipation  False
# Vision - Cryo          False
# Omnipresent            False
# Omniscient             False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
The shared keys between the two data frames is the 'name'column in df1 and the column_headers in df2. i will use the left joining of the data frames.
"""
# Out:
# "\nThe shared keys between the two data frames is the 'name'column in df1 and the column_headers in df2. i will use the left joining of the data frames.\n"

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
# Your code here (create more cells as needed)
# write a code that reshapes the df2 column_headers to be in rows formart as df1
# Set 'name' as the index for df1
heroes_df.set_index('name', inplace=True)

# Transpose df2 so that columns become rows
powers_df= powers_df.T
# join the two datas with the left join form
heroes_and_powers_df= heroes_df.join(powers_df)
print(heroes_and_powers_df)
# Out:
#                  Gender Eye color               Race        Hair color  \
# name
# A-Bomb             Male    yellow              Human           No Hair
# Abe Sapien         Male      blue      Icthyo Sapien           No Hair
# Abin Sur           Male      blue            Ungaran           No Hair
# Abomination        Male     green  Human / Radiation           No Hair
# Abraxas            Male      blue      Cosmic Entity             Black
# ...                 ...       ...                ...               ...
# Yellowjacket II  Female      blue              Human  Strawberry Blond
# Ymir               Male     white        Frost Giant           No Hair
# Yoda               Male     brown     Yoda's species             White
# Zatanna          Female      blue              Human             Black
# Zoom               Male       red                  -             Brown
#
#                  Height          Publisher Skin color Alignment  Weight  \
# name
# A-Bomb            203.0      Marvel Comics          -      good   441.0
# Abe Sapien        191.0  Dark Horse Comics       blue      good    65.0
# Abin Sur          185.0          DC Comics        red      good    90.0
# Abomination       203.0      Marvel Comics          -       bad   441.0
# Abraxas           -99.0      Marvel Comics          -       bad   -99.0
# ...                 ...                ...        ...       ...     ...
# Yellowjacket II   165.0      Marvel Comics          -      good    52.0
# Ymir              304.8      Marvel Comics      white      good   -99.0
# Yoda               66.0       George Lucas      green      good    17.0
# Zatanna           170.0          DC Comics          -      good    57.0
# Zoom              185.0          DC Comics          -       bad    81.0
#
#                 Agility  ... Web Creation Reality Warping Odin Force  \
# name                     ...
# A-Bomb            False  ...        False           False      False
# Abe Sapien         True  ...        False           False      False
# Abin Sur          False  ...        False           False      False
# Abomination       False  ...        False           False      False
# Abraxas           False  ...        False           False      False
# ...                 ...  ...          ...             ...        ...
# Yellowjacket II   False  ...        False           False      False
# Ymir              False  ...        False           False      False
# Yoda               True  ...        False           False      False
# Zatanna           False  ...        False           False      False
# Zoom              False  ...        False           False      False
#
#                 Symbiote Costume Speed Force Phoenix Force  \
# name
# A-Bomb                     False       False         False
# Abe Sapien                 False       False         False
# Abin Sur                   False       False         False
# Abomination                False       False         False
# Abraxas                    False       False         False
# ...                          ...         ...           ...
# Yellowjacket II            False       False         False
# Ymir                       False       False         False
# Yoda                       False       False         False
# Zatanna                    False       False         False
# Zoom                       False       False         False
#
#                 Molecular Dissipation Vision - Cryo Omnipresent Omniscient
# name
# A-Bomb                          False         False       False      False
# Abe Sapien                      False         False       False      False
# Abin Sur                        False         False       False      False
# Abomination                     False         False       False      False
# Abraxas                         False         False       False      False
# ...                               ...           ...         ...        ...
# Yellowjacket II                 False         False       False      False
# Ymir                            False         False       False      False
# Yoda                            False         False       False      False
# Zatanna                         False         False       False      False
# Zoom                            False         False       False      False
#
# [719 rows x 176 columns]

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a DataFrame with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 719

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you might need to
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
#heroes_and_powers_df["Power Count"] = sum(
   # [heroes_and_powers_df[power_name] for power_name in powers_df.index]
#)
#heroes_and_powers_df
# Check column names
print(heroes_and_powers_df.columns)

# Check index names in powers_df
print(powers_df.index)

# Check for missing names
for power_name in powers_df.index:
    if power_name not in heroes_and_powers_df.columns:
        print(f"Missing column: {power_name}")
# Out:
# Index(['Gender', 'Eye color', 'Race', 'Hair color', 'Height', 'Publisher',
#        'Skin color', 'Alignment', 'Weight', 'Agility',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=176)
# Index(['3-D Man', 'A-Bomb', 'Abe Sapien', 'Abin Sur', 'Abomination', 'Abraxas',
#        'Absorbing Man', 'Adam Monroe', 'Adam Strange', 'Agent Bob',
#        ...
#        'Wonder Man', 'Wonder Woman', 'X-23', 'X-Man', 'Yellowjacket',
#        'Yellowjacket II', 'Ymir', 'Yoda', 'Zatanna', 'Zoom'],
#       dtype='object', length=667)
# Missing column: 3-D Man
# Missing column: A-Bomb
# Missing column: Abe Sapien
# Missing column: Abin Sur
# Missing column: Abomination
# Missing column: Abraxas
# Missing column: Absorbing Man
# Missing column: Adam Monroe
# Missing column: Adam Strange
# Missing column: Agent Bob
# Missing column: Agent Zero
# Missing column: Air-Walker
# Missing column: Ajax
# Missing column: Alan Scott
# Missing column: Alex Mercer
# Missing column: Alex Woolsly
# Missing column: Alien
# Missing column: Allan Quatermain
# Missing column: Amazo
# Missing column: Ammo
# Missing column: Ando Masahashi
# Missing column: Angel
# Missing column: Angel Dust
# Missing column: Angel Salvadore
# Missing column: Angela
# Missing column: Animal Man
# Missing column: Annihilus
# Missing column: Ant-Man
# Missing column: Ant-Man II
# Missing column: Anti-Monitor
# Missing column: Anti-Spawn
# Missing column: Anti-Venom
# Missing column: Apocalypse
# Missing column: Aquababy
# Missing column: Aqualad
# Missing column: Aquaman
# Missing column: Arachne
# Missing column: Archangel
# Missing column: Arclight
# Missing column: Ardina
# Missing column: Ares
# Missing column: Ariel
# Missing column: Armor
# Missing column: Astro Boy
# Missing column: Atlas
# Missing column: Atom
# Missing column: Atom Girl
# Missing column: Atom II
# Missing column: Atom III
# Missing column: Atom IV
# Missing column: Aurora
# Missing column: Azazel
# Missing column: Azrael
# Missing column: Aztar
# Missing column: Bananaman
# Missing column: Bane
# Missing column: Banshee
# Missing column: Bantam
# Missing column: Batgirl
# Missing column: Batgirl IV
# Missing column: Batgirl VI
# Missing column: Batman
# Missing column: Batman II
# Missing column: Battlestar
# Missing column: Batwoman V
# Missing column: Beak
# Missing column: Beast
# Missing column: Beast Boy
# Missing column: Ben 10
# Missing column: Beta Ray Bill
# Missing column: Beyonder
# Missing column: Big Barda
# Missing column: Big Daddy
# Missing column: Big Man
# Missing column: Bill Harken
# Missing column: Billy Kincaid
# Missing column: Binary
# Missing column: Bionic Woman
# Missing column: Bird-Brain
# Missing column: Bird-Man
# Missing column: Bird-Man II
# Missing column: Birdman
# Missing column: Bishop
# Missing column: Bizarro
# Missing column: Bizarro-Girl
# Missing column: Black Abbott
# Missing column: Black Adam
# Missing column: Black Bolt
# Missing column: Black Canary
# Missing column: Black Cat
# Missing column: Black Flash
# Missing column: Black Knight III
# Missing column: Black Lightning
# Missing column: Black Mamba
# Missing column: Black Manta
# Missing column: Black Panther
# Missing column: Black Vulcan
# Missing column: Black Widow
# Missing column: Blackout
# Missing column: Blackwing
# Missing column: Blackwulf
# Missing column: Blade
# Missing column: Bling!
# Missing column: Blink
# Missing column: Blizzard
# Missing column: Blizzard II
# Missing column: Blob
# Missing column: Bloodaxe
# Missing column: Bloodhawk
# Missing column: Bloodwraith
# Missing column: Blue Beetle
# Missing column: Blue Beetle II
# Missing column: Blue Beetle III
# Missing column: Blue Streak
# Missing column: Boba Fett
# Missing column: Bomb Queen
# Missing column: Boom-Boom
# Missing column: Booster Gold
# Missing column: Box IV
# Missing column: Bradley
# Missing column: Brainiac
# Missing column: Brainiac 5
# Missing column: Brother Voodoo
# Missing column: Brundlefly
# Missing column: Buffy
# Missing column: Bullseye
# Missing column: Bumblebee
# Missing column: Bumbleboy
# Missing column: Bushido
# Missing column: Cable
# Missing column: Callisto
# Missing column: Cameron Hicks
# Missing column: Cannonball
# Missing column: Captain America
# Missing column: Captain Atom
# Missing column: Captain Britain
# Missing column: Captain Cold
# Missing column: Captain Epic
# Missing column: Captain Hindsight
# Missing column: Captain Marvel
# Missing column: Captain Marvel II
# Missing column: Captain Midnight
# Missing column: Captain Planet
# Missing column: Captain Universe
# Missing column: Carnage
# Missing column: Cat
# Missing column: Catwoman
# Missing column: Century
# Missing column: Cerebra
# Missing column: Chamber
# Missing column: Chameleon
# Missing column: Changeling
# Missing column: Cheetah
# Missing column: Cheetah II
# Missing column: Cheetah III
# Missing column: Chromos
# Missing column: Chuck Norris
# Missing column: Citizen Steel
# Missing column: Claire Bennet
# Missing column: Clayface
# Missing column: Cloak
# Missing column: Cogliostro
# Missing column: Colossus
# Missing column: Concrete
# Missing column: Copycat
# Missing column: Cottonmouth
# Missing column: Crimson Crusader
# Missing column: Crimson Dynamo
# Missing column: Crystal
# Missing column: Curse
# Missing column: Cy-Gor
# Missing column: Cyborg
# Missing column: Cyborg Superman
# Missing column: Cyclops
# Missing column: DL Hawkins
# Missing column: Dagger
# Missing column: Daphne Powell
# Missing column: Daredevil
# Missing column: Darkhawk
# Missing column: Darkman
# Missing column: Darkseid
# Missing column: Darkstar
# Missing column: Darth Maul
# Missing column: Darth Vader
# Missing column: Dash
# Missing column: Data
# Missing column: Dazzler
# Missing column: Deadman
# Missing column: Deadpool
# Missing column: Deadshot
# Missing column: Deathlok
# Missing column: Deathstroke
# Missing column: Dementor
# Missing column: Demogoblin
# Missing column: Destroyer
# Missing column: Diamondback
# Missing column: Doc Samson
# Missing column: Doctor Doom
# Missing column: Doctor Doom II
# Missing column: Doctor Fate
# Missing column: Doctor Octopus
# Missing column: Doctor Poison
# Missing column: Doctor Strange
# Missing column: Domino
# Missing column: Donatello
# Missing column: Donna Troy
# Missing column: Doomsday
# Missing column: Doppelganger
# Missing column: Dormammu
# Missing column: Dr Manhattan
# Missing column: Drax the Destroyer
# Missing column: Ego
# Missing column: Elastigirl
# Missing column: Electro
# Missing column: Elektra
# Missing column: Elle Bishop
# Missing column: Elongated Man
# Missing column: Emma Frost
# Missing column: Enchantress
# Missing column: Energy
# Missing column: Ethan Hunt
# Missing column: Etrigan
# Missing column: Evil Deadpool
# Missing column: Evilhawk
# Missing column: Exodus
# Missing column: Fabian Cortez
# Missing column: Falcon
# Missing column: Fallen One II
# Missing column: Faora
# Missing column: Feral
# Missing column: Fighting Spirit
# Missing column: Fin Fang Foom
# Missing column: Fire
# Missing column: Firebird
# Missing column: Firelord
# Missing column: Firestar
# Missing column: Firestorm
# Missing column: Flash
# Missing column: Flash Gordon
# Missing column: Flash II
# Missing column: Flash III
# Missing column: Flash IV
# Missing column: Forge
# Missing column: Franklin Richards
# Missing column: Frenzy
# Missing column: Frigga
# Missing column: Galactus
# Missing column: Gambit
# Missing column: Gamora
# Missing column: Garbage Man
# Missing column: Gary Bell
# Missing column: General Zod
# Missing column: Genesis
# Missing column: Ghost Rider
# Missing column: Ghost Rider II
# Missing column: Giganta
# Missing column: Gladiator
# Missing column: Goblin Queen
# Missing column: Godzilla
# Missing column: Gog
# Missing column: Goku
# Missing column: Goliath IV
# Missing column: Gorilla Grodd
# Missing column: Granny Goodness
# Missing column: Gravity
# Missing column: Greedo
# Missing column: Green Arrow
# Missing column: Green Goblin
# Missing column: Green Goblin II
# Missing column: Green Goblin III
# Missing column: Green Goblin IV
# Missing column: Groot
# Missing column: Guy Gardner
# Missing column: Hal Jordan
# Missing column: Han Solo
# Missing column: Hancock
# Missing column: Harley Quinn
# Missing column: Harry Potter
# Missing column: Havok
# Missing column: Hawk
# Missing column: Hawkeye
# Missing column: Hawkeye II
# Missing column: Hawkgirl
# Missing column: Hawkman
# Missing column: Heat Wave
# Missing column: Hela
# Missing column: Hellboy
# Missing column: Hellcat
# Missing column: Hellgramite
# Missing column: Hellstorm
# Missing column: Hercules
# Missing column: Hiro Nakamura
# Missing column: Hit-Girl
# Missing column: Hobgoblin
# Missing column: Hollow
# Missing column: Hope Summers
# Missing column: Hulk
# Missing column: Human Torch
# Missing column: Huntress
# Missing column: Husk
# Missing column: Hybrid
# Missing column: Hydro-Man
# Missing column: Hyperion
# Missing column: Iceman
# Missing column: Impulse
# Missing column: Indiana Jones
# Missing column: Indigo
# Missing column: Ink
# Missing column: Invisible Woman
# Missing column: Iron Fist
# Missing column: Iron Man
# Missing column: Iron Monger
# Missing column: Isis
# Missing column: JJ Powell
# Missing column: Jack of Hearts
# Missing column: Jack-Jack
# Missing column: James Bond
# Missing column: James T. Kirk
# Missing column: Jar Jar Binks
# Missing column: Jason Bourne
# Missing column: Jean Grey
# Missing column: Jean-Luc Picard
# Missing column: Jennifer Kale
# Missing column: Jessica Cruz
# Missing column: Jessica Jones
# Missing column: Jim Powell
# Missing column: Johann Krauss
# Missing column: John Constantine
# Missing column: John Stewart
# Missing column: John Wraith
# Missing column: Joker
# Missing column: Jolt
# Missing column: Jubilee
# Missing column: Judge Dredd
# Missing column: Juggernaut
# Missing column: Junkpile
# Missing column: Justice
# Missing column: K-2SO
# Missing column: Kang
# Missing column: Karate Kid
# Missing column: Kathryn Janeway
# Missing column: Katniss Everdeen
# Missing column: Kevin 11
# Missing column: Kick-Ass
# Missing column: Kid Flash
# Missing column: Killer Croc
# Missing column: Killer Frost
# Missing column: Kilowog
# Missing column: King Kong
# Missing column: King Shark
# Missing column: Klaw
# Missing column: Kool-Aid Man
# Missing column: Kraven II
# Missing column: Kraven the Hunter
# Missing column: Krypto
# Missing column: Kyle Rayner
# Missing column: Kylo Ren
# Missing column: Lady Bullseye
# Missing column: Lady Deathstrike
# Missing column: Lara Croft
# Missing column: Leader
# Missing column: Leech
# Missing column: Legion
# Missing column: Leonardo
# Missing column: Lex Luthor
# Missing column: Light Lass
# Missing column: Lightning Lad
# Missing column: Lightning Lord
# Missing column: Little Epic
# Missing column: Living Brain
# Missing column: Living Tribunal
# Missing column: Liz Sherman
# Missing column: Lizard
# Missing column: Lobo
# Missing column: Loki
# Missing column: Longshot
# Missing column: Lord Voldemort
# Missing column: Luke Cage
# Missing column: Luke Campbell
# Missing column: Luke Skywalker
# Missing column: Luna
# Missing column: Lyja
# Missing column: MODOK
# Missing column: Mach-IV
# Missing column: Machine Man
# Missing column: Magneto
# Missing column: Magog
# Missing column: Magus
# Missing column: Man of Miracles
# Missing column: Man-Bat
# Missing column: Man-Thing
# Missing column: Man-Wolf
# Missing column: Mandarin
# Missing column: Mantis
# Missing column: Martian Manhunter
# Missing column: Marvel Girl
# Missing column: Master Brood
# Missing column: Master Chief
# Missing column: Match
# Missing column: Matt Parkman
# Missing column: Maverick
# Missing column: Maxima
# Missing column: Maya Herrera
# Missing column: Medusa
# Missing column: Meltdown
# Missing column: Mephisto
# Missing column: Mera
# Missing column: Metallo
# Missing column: Metamorpho
# Missing column: Metron
# Missing column: Micah Sanders
# Missing column: Michelangelo
# Missing column: Micro Lad
# Missing column: Mimic
# Missing column: Minna Murray
# Missing column: Misfit
# Missing column: Miss Martian
# Missing column: Mister Fantastic
# Missing column: Mister Freeze
# Missing column: Mister Knife
# Missing column: Mister Mxyzptlk
# Missing column: Mister Sinister
# Missing column: Mockingbird
# Missing column: Mohinder Suresh
# Missing column: Molten Man
# Missing column: Monarch
# Missing column: Monica Dawson
# Missing column: Moon Knight
# Missing column: Moonstone
# Missing column: Morlun
# Missing column: Moses Magnum
# Missing column: Mr Immortal
# Missing column: Mr Incredible
# Missing column: Ms Marvel II
# Missing column: Multiple Man
# Missing column: Mysterio
# Missing column: Mystique
# Missing column: Namor
# Missing column: Namora
# Missing column: Namorita
# Missing column: Naruto Uzumaki
# Missing column: Nathan Petrelli
# Missing column: Nebula
# Missing column: Negasonic Teenage Warhead
# Missing column: Nick Fury
# Missing column: Nightcrawler
# Missing column: Nightwing
# Missing column: Niki Sanders
# Missing column: Nina Theroux
# Missing column: Northstar
# Missing column: Nova
# Missing column: Odin
# Missing column: Offspring
# Missing column: One Punch Man
# Missing column: One-Above-All
# Missing column: Onslaught
# Missing column: Oracle
# Missing column: Orion
# Missing column: Osiris
# Missing column: Overtkill
# Missing column: Ozymandias
# Missing column: Parademon
# Missing column: Peek-a-Boo
# Missing column: Penance II
# Missing column: Penguin
# Missing column: Peter Petrelli
# Missing column: Phantom
# Missing column: Phantom Girl
# Missing column: Phoenix
# Missing column: Plantman
# Missing column: Plastic Man
# Missing column: Plastique
# Missing column: Poison Ivy
# Missing column: Polaris
# Missing column: Power Girl
# Missing column: Predator
# Missing column: Professor X
# Missing column: Professor Zoom
# Missing column: Proto-Goblin
# Missing column: Psylocke
# Missing column: Punisher
# Missing column: Purple Man
# Missing column: Pyro
# Missing column: Q
# Missing column: Quantum
# Missing column: Queen Hippolyta
# Missing column: Question
# Missing column: Quicksilver
# Missing column: Quill
# Missing column: Ra's Al Ghul
# Missing column: Rachel Pirzad
# Missing column: Rambo
# Missing column: Raphael
# Missing column: Raven
# Missing column: Ray
# Missing column: Razor-Fist II
# Missing column: Reactron
# Missing column: Red Arrow
# Missing column: Red Hood
# Missing column: Red Hulk
# Missing column: Red Mist
# Missing column: Red Robin
# Missing column: Red Skull
# Missing column: Red Tornado
# Missing column: Redeemer II
# Missing column: Redeemer III
# Missing column: Rey
# Missing column: Rhino
# Missing column: Rick Flag
# Missing column: Riddler
# Missing column: Rip Hunter
# Missing column: Ripcord
# Missing column: Robin
# Missing column: Robin II
# Missing column: Robin III
# Missing column: Robin V
# Missing column: Robin VI
# Missing column: Rocket Raccoon
# Missing column: Rogue
# Missing column: Rorschach
# Missing column: SHDB
# Missing column: Sabretooth
# Missing column: Sage
# Missing column: Sandman
# Missing column: Sasquatch
# Missing column: Sauron
# Missing column: Savage Dragon
# Missing column: Scarecrow
# Missing column: Scarlet Spider
# Missing column: Scarlet Spider II
# Missing column: Scarlet Witch
# Missing column: Scorpia
# Missing column: Scorpion
# Missing column: Sebastian Shaw
# Missing column: Sentry
# Missing column: Shadow King
# Missing column: Shadow Lass
# Missing column: Shadowcat
# Missing column: Shang-Chi
# Missing column: Shatterstar
# Missing column: She-Hulk
# Missing column: She-Thing
# Missing column: Shocker
# Missing column: Shriek
# Missing column: Sif
# Missing column: Silk
# Missing column: Silk Spectre
# Missing column: Silk Spectre II
# Missing column: Silver Surfer
# Missing column: Silverclaw
# Missing column: Simon Baz
# Missing column: Sinestro
# Missing column: Siren
# Missing column: Siren II
# Missing column: Siryn
# Missing column: Skaar
# Missing column: Snowbird
# Missing column: Sobek
# Missing column: Solomon Grundy
# Missing column: Songbird
# Missing column: Space Ghost
# Missing column: Spawn
# Missing column: Spectre
# Missing column: Speedball
# Missing column: Speedy
# Missing column: Spider-Girl
# Missing column: Spider-Gwen
# Missing column: Spider-Man
# Missing column: Spider-Woman
# Missing column: Spider-Woman III
# Missing column: Spider-Woman IV
# Missing column: Spock
# Missing column: Spyke
# Missing column: Star-Lord
# Missing column: Stardust
# Missing column: Starfire
# Missing column: Stargirl
# Missing column: Static
# Missing column: Steel
# Missing column: Stephanie Powell
# Missing column: Steppenwolf
# Missing column: Storm
# Missing column: Stormtrooper
# Missing column: Stretch Armstrong
# Missing column: Sunspot
# Missing column: Superboy
# Missing column: Superboy-Prime
# Missing column: Supergirl
# Missing column: Superman
# Missing column: Swamp Thing
# Missing column: Swarm
# Missing column: Sylar
# Missing column: Synch
# Missing column: T-1000
# Missing column: T-800
# Missing column: T-850
# Missing column: T-X
# Missing column: TEST
# Missing column: Taskmaster
# Missing column: Tempest
# Missing column: Thanos
# Missing column: The Cape
# Missing column: The Comedian
# Missing column: Thing
# Missing column: Thor
# Missing column: Thor Girl
# Missing column: Thunderbird
# Missing column: Thunderbird III
# Missing column: Thunderstrike
# Missing column: Thundra
# Missing column: Tiger Shark
# Missing column: Tigra
# Missing column: Tinkerer
# Missing column: Titan
# Missing column: Toad
# Missing column: Tommy Clarke
# Missing column: Toxin
# Missing column: Tracy Strauss
# Missing column: Trickster
# Missing column: Trigon
# Missing column: Triplicate Girl
# Missing column: Triton
# Missing column: Tyrant
# Missing column: Ultragirl
# Missing column: Ultron
# Missing column: Utgard-Loki
# Missing column: Valerie Hart
# Missing column: Valkyrie
# Missing column: Vanisher
# Missing column: Vegeta
# Missing column: Venom
# Missing column: Venom II
# Missing column: Venom III
# Missing column: Venompool
# Missing column: Vertigo II
# Missing column: Vibe
# Missing column: Vindicator
# Missing column: Violator
# Missing column: Violet Parr
# Missing column: Vision
# Missing column: Vixen
# Missing column: Vulture
# Missing column: Walrus
# Missing column: War Machine
# Missing column: Warlock
# Missing column: Warp
# Missing column: Warpath
# Missing column: Wasp
# Missing column: Watcher
# Missing column: Weapon XI
# Missing column: White Canary
# Missing column: Wildfire
# Missing column: Winter Soldier
# Missing column: Wolfsbane
# Missing column: Wolverine
# Missing column: Wonder Girl
# Missing column: Wonder Man
# Missing column: Wonder Woman
# Missing column: X-23
# Missing column: X-Man
# Missing column: Yellowjacket
# Missing column: Yellowjacket II
# Missing column: Ymir
# Missing column: Yoda
# Missing column: Zatanna
# Missing column: Zoom

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"], y=heroes_and_powers_df["Power Count"], alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
plt. show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Power Count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 6
#       1 # Run this cell without changes
#       3 fig, ax = plt.subplots(figsize=(16, 8))
#       5 ax.scatter(
# ----> 6     x=heroes_and_powers_df["Height"], y=heroes_and_powers_df["Power Count"], alpha=0.3
#       7 )
#       9 ax.set_xlabel("Height (cm)")
#      10 ax.set_ylabel("Number of Superpowers")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Power Count'

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(x=question_2_df["Height"], y=question_2_df["Power Count"], alpha=0.3)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[
    (question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")
]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male",
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female",
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other",
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
# Your code here (create more cells as needed)

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == [
    "DC Comics",
    "Marvel Comics",
    "Superpower Name",
]

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(
    by="Marvel Comics", ascending=False
)[:5]
marvel_most_common

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"], height=marvel_most_common["Marvel Comics"]
)
ax2.bar(x=dc_most_common["Superpower Name"], height=dc_most_common["DC Comics"])

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
None
"""

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
